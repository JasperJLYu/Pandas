# %%
# 导入包
import pandas as pd

# %%
# 读取数据并查看部分数据
data_path = "E:/code/jupyter/data_analysis/pandas/demos/长沙二手房新房数据分析/长沙二手房_230821_1692604744.xlsx"
df = pd.read_excel(data_path)
df.head()
# Out:
#   city area                      title  \
# 0   长沙  长沙县            房子带地暖，业主自住装修！！！
# 1   长沙  长沙县  单价4字头的次新小区，纯毛坯出售，看房方便，格局好
# 2   长沙  长沙县  经典“3+1”户型大三房，单独入户花园，南北双阳台
# 3   长沙  长沙县  地铁口螺丝塘站，全新精装空置4年从未入住，随时看房
# 4   长沙  长沙县   地铁口 吾悦广场旁 恒基凯旋门 精装房毛坯价出售
#
#                                              link  \
# 0  https://cs.ke.com/ershoufang/104109880333.html
# 1  https://cs.ke.com/ershoufang/104109880898.html
# 2  https://cs.ke.com/ershoufang/104109880914.html
# 3  https://cs.ke.com/ershoufang/104109881161.html
# 4  https://cs.ke.com/ershoufang/104109884832.html
#
#                                                  img     flood  \
# 0  https://s1.ljcdn.com/pegasus/redskull/images/c...       山水湾
# 1  https://s1.ljcdn.com/pegasus/redskull/images/c...   恒广国际物流园
# 2  https://s1.ljcdn.com/pegasus/redskull/images/c...  湖湘奥林匹克花园
# 3  https://s1.ljcdn.com/pegasus/redskull/images/c...  MOMA当代广场
# 4  https://s1.ljcdn.com/pegasus/redskull/images/c...     恒基凯旋门
#
#                          houseInfo                 tag  totalPrice  unitPrice
# 0    低楼层(共6层)|2011年建|3室2厅|87.6平米|南  近地铁|满五年|VR看装修|随时看房        66.0       7535
# 1          高楼层(共6层)2室2厅|85.34平米|南北          VR看装修|随时看房        38.0       4453
# 2        低楼层(共28层)3室2厅|116.55平米|南北               VR看装修        77.8       6676
# 3   低楼层(共34层)|2014年建|3室2厅|84.5平米|南  近地铁|满五年|VR看装修|随时看房        67.0       7929
# 4  低楼层(共33层)|2010年建|2室2厅|96.42平米|南      满五年|VR看装修|随时看房        82.0       8505

# %%
# 数据预处理
# 删除重复值
df.drop_duplicates(inplace=True)

# 删除link和img两列
df.drop(['link', 'img'], axis=1, inplace=True)

df.head()
# Out:
#   city area                      title     flood  \
# 0   长沙  长沙县            房子带地暖，业主自住装修！！！       山水湾
# 1   长沙  长沙县  单价4字头的次新小区，纯毛坯出售，看房方便，格局好   恒广国际物流园
# 2   长沙  长沙县  经典“3+1”户型大三房，单独入户花园，南北双阳台  湖湘奥林匹克花园
# 3   长沙  长沙县  地铁口螺丝塘站，全新精装空置4年从未入住，随时看房  MOMA当代广场
# 4   长沙  长沙县   地铁口 吾悦广场旁 恒基凯旋门 精装房毛坯价出售     恒基凯旋门
#
#                          houseInfo                 tag  totalPrice  unitPrice
# 0    低楼层(共6层)|2011年建|3室2厅|87.6平米|南  近地铁|满五年|VR看装修|随时看房        66.0       7535
# 1          高楼层(共6层)2室2厅|85.34平米|南北          VR看装修|随时看房        38.0       4453
# 2        低楼层(共28层)3室2厅|116.55平米|南北               VR看装修        77.8       6676
# 3   低楼层(共34层)|2014年建|3室2厅|84.5平米|南  近地铁|满五年|VR看装修|随时看房        67.0       7929
# 4  低楼层(共33层)|2010年建|2室2厅|96.42平米|南      满五年|VR看装修|随时看房        82.0       8505

# %%
# 查看总体信息
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20982 entries, 0 to 20981
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        20982 non-null  object
#  1   area        20982 non-null  object
#  2   title       20982 non-null  object
#  3   flood       20982 non-null  object
#  4   houseInfo   20982 non-null  object
#  5   tag         20976 non-null  object
#  6   totalPrice  20982 non-null  float64
#  7   unitPrice   20982 non-null  int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.3+ MB

# %%
df["area"].unique()
# Out:
# array(['长沙县', '浏阳', '宁乡', '望城', '芙蓉', '开福', '天心', '岳麓', '雨花'],
#       dtype=object)

# %%
# 任务1
# 统计各行政区内二手房数量，并降序输出
sale_count = df.groupby("area")["title"].count().sort_values(ascending=False)
print(f"各行政区在售二手房数量: \n {sale_count}")

# 各行政区内售房单价均值
mean_price = df.groupby("area")["unitPrice"].mean().round(2).sort_values()
print(f"各行政区内二手房售卖单价均值: {mean_price}")
print(f"平均单价最高的行政区: {mean_price.idxmax()} -> {mean_price.max()}")
print(f"平均单价最低的行政区: {mean_price.idxmin()} -> {mean_price.min():.2f}")
# Out:
# 各行政区在售二手房数量:
#  area
# 天心     3000
# 望城     3000
# 开福     3000
# 长沙县    3000
# 芙蓉     3000
# 雨花     3000
# 岳麓     2970
# 宁乡       10
# 浏阳        2
# Name: title, dtype: int64
# 各行政区内二手房售卖单价均值: area
# 浏阳      6595.50
# 宁乡      6654.10
# 长沙县     8123.77
# 望城      8920.19
# 芙蓉     10067.58
# 天心     10606.15
# 雨花     11005.40
# 开福     11610.78
# 岳麓     14182.58
# Name: unitPrice, dtype: float64
# 平均单价最高的行政区: 岳麓 -> 14182.58
# 平均单价最低的行政区: 浏阳 -> 6595.50

# %%
df.head()
# Out:
#   city area                      title     flood  \
# 0   长沙  长沙县            房子带地暖，业主自住装修！！！       山水湾
# 1   长沙  长沙县  单价4字头的次新小区，纯毛坯出售，看房方便，格局好   恒广国际物流园
# 2   长沙  长沙县  经典“3+1”户型大三房，单独入户花园，南北双阳台  湖湘奥林匹克花园
# 3   长沙  长沙县  地铁口螺丝塘站，全新精装空置4年从未入住，随时看房  MOMA当代广场
# 4   长沙  长沙县   地铁口 吾悦广场旁 恒基凯旋门 精装房毛坯价出售     恒基凯旋门
#
#                          houseInfo                 tag  totalPrice  unitPrice
# 0    低楼层(共6层)|2011年建|3室2厅|87.6平米|南  近地铁|满五年|VR看装修|随时看房        66.0       7535
# 1          高楼层(共6层)2室2厅|85.34平米|南北          VR看装修|随时看房        38.0       4453
# 2        低楼层(共28层)3室2厅|116.55平米|南北               VR看装修        77.8       6676
# 3   低楼层(共34层)|2014年建|3室2厅|84.5平米|南  近地铁|满五年|VR看装修|随时看房        67.0       7929
# 4  低楼层(共33层)|2010年建|2室2厅|96.42平米|南      满五年|VR看装修|随时看房        82.0       8505

# %%
# 任务2
# 对 houseInfo 进行拆分
# 定义拆分函数
def split_house_info(info):
    parts = str(info).split("|")
    # 默认值
    floor, year, spec, size, orientation = None, None, None, None, None
    
    if len(parts) == 5:
        # 正常情况：5 个字段
        floor, year, spec, size, orientation = parts
    elif len(parts) == 4:
        # 少了“建房时间” 或 少了“朝向”
        if "年建" in parts[1]:   # 第二个字段含“建” → 说明是建房时间
            floor, year, spec, size = parts
        else:  # 否则说明缺少建房时间
            floor, spec, size, orientation = parts
    elif len(parts) == 3:
        if "室" in parts[0]:
            parts.append(parts[0][-4:])
            parts[0] = parts[0][:-4]
        # 可能缺少“建房时间”和“朝向”
        floor, size, orientation, spec = parts
    elif len(parts) == 2:
        floor, spec = parts
    else:
        floor = parts[0]
    
    return pd.Series([floor, year, spec, size, orientation],
                     index=["楼层位置", "建房时间", "房屋规格", "房屋大小", "房屋朝向"])

# %%
# 应用拆分函数
df_split = df["houseInfo"].apply(split_house_info)
df_split.head()
# Out:
#         楼层位置    建房时间  房屋规格      房屋大小 房屋朝向
# 0   低楼层(共6层)  2011年建  3室2厅    87.6平米    南
# 1   高楼层(共6层)    None  2室2厅   85.34平米   南北
# 2  低楼层(共28层)    None  3室2厅  116.55平米   南北
# 3  低楼层(共34层)  2014年建  3室2厅    84.5平米    南
# 4  低楼层(共33层)  2010年建  2室2厅   96.42平米    南

# %%
# 4. 合并到原数据
df_new = pd.concat([df, df_split], axis=1)

# %%
df_new.head()
# Out:
#   city area                      title     flood  \
# 0   长沙  长沙县            房子带地暖，业主自住装修！！！       山水湾
# 1   长沙  长沙县  单价4字头的次新小区，纯毛坯出售，看房方便，格局好   恒广国际物流园
# 2   长沙  长沙县  经典“3+1”户型大三房，单独入户花园，南北双阳台  湖湘奥林匹克花园
# 3   长沙  长沙县  地铁口螺丝塘站，全新精装空置4年从未入住，随时看房  MOMA当代广场
# 4   长沙  长沙县   地铁口 吾悦广场旁 恒基凯旋门 精装房毛坯价出售     恒基凯旋门
#
#                          houseInfo                 tag  totalPrice  unitPrice  \
# 0    低楼层(共6层)|2011年建|3室2厅|87.6平米|南  近地铁|满五年|VR看装修|随时看房        66.0       7535
# 1          高楼层(共6层)2室2厅|85.34平米|南北          VR看装修|随时看房        38.0       4453
# 2        低楼层(共28层)3室2厅|116.55平米|南北               VR看装修        77.8       6676
# 3   低楼层(共34层)|2014年建|3室2厅|84.5平米|南  近地铁|满五年|VR看装修|随时看房        67.0       7929
# 4  低楼层(共33层)|2010年建|2室2厅|96.42平米|南      满五年|VR看装修|随时看房        82.0       8505
#
#         楼层位置    建房时间  房屋规格      房屋大小 房屋朝向
# 0   低楼层(共6层)  2011年建  3室2厅    87.6平米    南
# 1   高楼层(共6层)    None  2室2厅   85.34平米   南北
# 2  低楼层(共28层)    None  3室2厅  116.55平米   南北
# 3  低楼层(共34层)  2014年建  3室2厅    84.5平米    南
# 4  低楼层(共33层)  2010年建  2室2厅   96.42平米    南

# %%
# 任务3
# 处理缺失值
df_new.isnull().sum()

# 删除缺失值
df_new.dropna(inplace=True)
df_new.isnull().sum()

# 房屋的朝向使用 unknown 填充
# df = df.fillna({"房屋朝向":"unknown"})
# df.isnull().sum()

# tag 使用 unknown 填充
# df = df.fillna({"tag":"unknown"})
# df.isnull().sum()

# 房屋大小使用均值填充
# df["房屋大小"] = df["房屋大小"].str.replace("平米", "", regex=False)
# df["房屋大小"] = pd.to_numeric(df["房屋大小"], errors="coerce")
# df = df.fillna(round(df["房屋大小"].mean(), 2))
# df["房屋大小"] = df["房屋大小"].astype(str) + "平米"
# df.head()
# Out:
# city          0
# area          0
# title         0
# flood         0
# houseInfo     0
# tag           0
# totalPrice    0
# unitPrice     0
# 楼层位置          0
# 建房时间          0
# 房屋规格          0
# 房屋大小          0
# 房屋朝向          0
# dtype: int64

# %%
# 任务4：统计不同楼层的房屋的售卖均价
data = df_new
data["houseInfo"] = data["houseInfo"].str[:3]
data.head()
# Out:
#   city area                      title     flood houseInfo  \
# 0   长沙  长沙县            房子带地暖，业主自住装修！！！       山水湾       低楼层
# 3   长沙  长沙县  地铁口螺丝塘站，全新精装空置4年从未入住，随时看房  MOMA当代广场       低楼层
# 4   长沙  长沙县   地铁口 吾悦广场旁 恒基凯旋门 精装房毛坯价出售     恒基凯旋门       低楼层
# 5   长沙  长沙县      此房户型周正，朝南户型，三个房间面积都可以      旭辉华庭       高楼层
# 6   长沙  长沙县         诚意出售，户型周正，楼层好，采光好！   中国铁建国际城       高楼层
#
#                   tag  totalPrice  unitPrice       楼层位置    建房时间  房屋规格  \
# 0  近地铁|满五年|VR看装修|随时看房        66.0       7535   低楼层(共6层)  2011年建  3室2厅
# 3  近地铁|满五年|VR看装修|随时看房        67.0       7929  低楼层(共34层)  2014年建  3室2厅
# 4      满五年|VR看装修|随时看房        82.0       8505  低楼层(共33层)  2010年建  2室2厅
# 5      满五年|VR看装修|随时看房        95.3       7590  高楼层(共34层)  2012年建  4室2厅
# 6           满五年|VR看装修        60.0       7439  高楼层(共30层)  2011年建  2室2厅
#
#        房屋大小 房屋朝向
# 0    87.6平米    南
# 3    84.5平米    南
# 4   96.42平米    南
# 5  125.56平米    南
# 6   80.66平米    南

# %%
# 根据楼层聚类，并求平均值
floor_mean = data.groupby("houseInfo")["unitPrice"].mean().round(2).sort_values(ascending=False)
floor_mean
# Out:
# houseInfo
# 低楼层    10960.64
# 中楼层    10762.76
# 高楼层    10701.70
# Name: unitPrice, dtype: float64

# %%
data.groupby(["area", "houseInfo"])["unitPrice"].mean().round(2)
# Out:
# area  houseInfo
# 天心    中楼层          10856.25
#       低楼层          11118.69
#       高楼层          11176.47
# 岳麓    中楼层          13698.60
#       低楼层          13684.91
#       高楼层          13546.53
# 开福    中楼层          11601.68
#       低楼层          11925.94
#       高楼层          11428.41
# 望城    中楼层           9001.86
#       低楼层           8935.24
#       高楼层           8867.58
# 芙蓉    中楼层          10224.04
#       低楼层          10580.52
#       高楼层          10228.96
# 长沙县   中楼层           8012.14
#       低楼层           8175.66
#       高楼层           7905.60
# 雨花    中楼层          10924.21
#       低楼层          11377.40
#       高楼层          10902.30
# Name: unitPrice, dtype: float64

# %%
# 任务5: 统计不同建房年份的房屋单价均值，找出历史均价最低的是哪一年
# 格式化建房时间
df_new["建房时间"] = df_new["建房时间"].str.replace("年建", "", regex=False)
df_new.head()
# Out:
#   city area                      title     flood houseInfo  \
# 0   长沙  长沙县            房子带地暖，业主自住装修！！！       山水湾       低楼层
# 3   长沙  长沙县  地铁口螺丝塘站，全新精装空置4年从未入住，随时看房  MOMA当代广场       低楼层
# 4   长沙  长沙县   地铁口 吾悦广场旁 恒基凯旋门 精装房毛坯价出售     恒基凯旋门       低楼层
# 5   长沙  长沙县      此房户型周正，朝南户型，三个房间面积都可以      旭辉华庭       高楼层
# 6   长沙  长沙县         诚意出售，户型周正，楼层好，采光好！   中国铁建国际城       高楼层
#
#                   tag  totalPrice  unitPrice       楼层位置  建房时间  房屋规格      房屋大小  \
# 0  近地铁|满五年|VR看装修|随时看房        66.0       7535   低楼层(共6层)  2011  3室2厅    87.6平米
# 3  近地铁|满五年|VR看装修|随时看房        67.0       7929  低楼层(共34层)  2014  3室2厅    84.5平米
# 4      满五年|VR看装修|随时看房        82.0       8505  低楼层(共33层)  2010  2室2厅   96.42平米
# 5      满五年|VR看装修|随时看房        95.3       7590  高楼层(共34层)  2012  4室2厅  125.56平米
# 6           满五年|VR看装修        60.0       7439  高楼层(共30层)  2011  2室2厅   80.66平米
#
#   房屋朝向
# 0    南
# 3    南
# 4    南
# 5    南
# 6    南

# %%
# 按年份聚类，并求每年的房屋均价
df_year = df_new.groupby("建房时间")["unitPrice"].mean().round(2)
# df_year = df_new.groupby("建房时间").agg(avgUnitPrice=("unitPrice", lambda x: round(x.mean(), 2)))

print(df_year)
print("=" * 10)

print(f"均值单价最低的年份是: {df_year.idxmax()} 年")

# 新增一列判断建房时间是否已满三年
from datetime import datetime
df_new["建房时间"] = pd.to_numeric(df_new["建房时间"], errors="coerce")
df_new["建房是否已满三年"] = (datetime.now().year - df_new["建房时间"]) >= 3
df_new.head()
# Out:
# 建房时间
# 1960     7122.00
# 1975     6429.00
# 1979     7327.50
# 1980     4911.00
# 1981     8810.00
# 1983     5861.00
# 1984     6967.00
# 1985     6489.00
# 1987     6610.00
# 1988     8231.80
# 1989     8370.21
# 1990     8920.21
# 1991     8226.57
# 1992     7399.25
# 1993     7213.64
# 1994     9926.39
# 1995     8366.16
# 1996     8320.77
# 1997     8020.57
# 1998     8268.07
# 1999     9284.62
# 2000     7901.75
# 2001     8501.55
# 2002     8562.87
# 2003     9708.65
# 2004     8285.57
# 2005     9640.06
# 2006     9301.27
# 2007     9587.27
# 2008    10253.41
# 2009    10582.13
# 2010    10624.13
# 2011    10138.38
# 2012    10923.85
# 2013    11299.71
# 2014    11769.30
# 2015    10942.66
# 2016    11907.62
# 2017    11468.21
# 2018    11730.91
# 2019    13599.74
# 2020    16547.50
# 2021    18091.22
# 2022    19400.75
# 2023    16666.33
# Name: unitPrice, dtype: float64
# ==========
# 均值单价最低的年份是: 2022 年
#   city area                      title     flood houseInfo  \
# 0   长沙  长沙县            房子带地暖，业主自住装修！！！       山水湾       低楼层
# 3   长沙  长沙县  地铁口螺丝塘站，全新精装空置4年从未入住，随时看房  MOMA当代广场       低楼层
# 4   长沙  长沙县   地铁口 吾悦广场旁 恒基凯旋门 精装房毛坯价出售     恒基凯旋门       低楼层
# 5   长沙  长沙县      此房户型周正，朝南户型，三个房间面积都可以      旭辉华庭       高楼层
# 6   长沙  长沙县         诚意出售，户型周正，楼层好，采光好！   中国铁建国际城       高楼层
#
#                   tag  totalPrice  unitPrice       楼层位置  建房时间  房屋规格      房屋大小  \
# 0  近地铁|满五年|VR看装修|随时看房        66.0       7535   低楼层(共6层)  2011  3室2厅    87.6平米
# 3  近地铁|满五年|VR看装修|随时看房        67.0       7929  低楼层(共34层)  2014  3室2厅    84.5平米
# 4      满五年|VR看装修|随时看房        82.0       8505  低楼层(共33层)  2010  2室2厅   96.42平米
# 5      满五年|VR看装修|随时看房        95.3       7590  高楼层(共34层)  2012  4室2厅  125.56平米
# 6           满五年|VR看装修        60.0       7439  高楼层(共30层)  2011  2室2厅   80.66平米
#
#   房屋朝向  建房是否已满三年
# 0    南      True
# 3    南      True
# 4    南      True
# 5    南      True
# 6    南      True

# %%
# 任务6: 岳麓区不同户型的房屋均价
house_1 = df_new[(df_new["area"] == "岳麓") & (df_new["房屋规格"] == "3室2厅")]
house_2 = df_new[(df_new["area"] == "岳麓") & (df_new["房屋规格"] =="4室1厅")]
house_1_avgUnitPrice = round(house_1["unitPrice"].mean(), 2)
house_2_avgUnitPrice = round(house_2["unitPrice"].mean(), 2)
print(f"岳麓区 3 室 2 厅的房屋售价均值为: {house_1_avgUnitPrice} 元.")
print(f"岳麓区 4 室 1 厅的房屋售价均值为: {house_2_avgUnitPrice} 元.")
print(f"岳麓区两种户型房屋售价均值差为: {house_2_avgUnitPrice - house_1_avgUnitPrice} 元.")
# Out:
# 岳麓区 3 室 2 厅的房屋售价均值为: 13820.48 元.
# 岳麓区 4 室 1 厅的房屋售价均值为: 15919.29 元.
# 岳麓区两种户型房屋售价均值差为: 2098.8100000000013 元.
